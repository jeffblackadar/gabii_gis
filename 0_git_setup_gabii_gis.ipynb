# %% [markdown]
# # Connect to Google Drive

# %%
import os
os.chdir('/content/drive/MyDrive/gabii_gis/')
# !pwd
#!git init .
# Out:
# /content/drive/MyDrive/gabii_gis

# %%
import os
os.chdir('/content/drive/MyDrive/gabii_gis/')
# !pwd
# Out:
# /content/drive/MyDrive/gabii_gis

# %%
# !git add -A

# %%
# !git config --global user.email "jeffblackadar@gmail.com"
# !git config --global user.name "jeffblackadar"
#!git config --global user.password ""

# %%
# !git pull https://github.com/jeffblackadar/gabii_gis.git
# Out:
# From https://github.com/jeffblackadar/gabii_gis
#  * branch            HEAD       -> FETCH_HEAD
# Already up to date.

# %%
# !git commit -m "map generator"
# Out:
# [main 75df883] map generator
#  2 files changed, 2 insertions(+), 1 deletion(-)
#  rewrite 0_git_setup_gabii_gis.ipynb (86%)
#  create mode 100644 gabii_map_generator.ipynb

# %%
#https://amitness.com/2020/06/google-colaboratory-tips/
import subprocess
input
print('Enter your pat:')
pat = input()
command = "git remote add origin https://"+pat+"@github.com/jeffblackadar/gabii_gis.git"
subprocess.call(command, shell=True)
command = "git remote set-url origin https://"+pat+"@github.com/jeffblackadar/gabii_gis.git"
subprocess.call(command, shell=True)
print("delete this output")

# %%
# !git remote -v
print("delete this output")

# %%
# !git push --set-upstream origin main
# Out:
# Counting objects: 3, done.
# Delta compression using up to 2 threads.
# Compressing objects: 100% (3/3), done.
# Writing objects: 100% (3/3), 3.87 KiB | 990.00 KiB/s, done.
# Total 3 (delta 0), reused 0 (delta 0)
# To https://github.com/jeffblackadar/gabii_gis.git
#    6d2f475..9fb6809  main -> main
# Branch 'main' set up to track remote branch 'main' from 'origin'.

# %%
# !git push
# Out:
# Counting objects: 4, done.
# Delta compression using up to 2 threads.
# Compressing objects: 100% (4/4), done.
# Writing objects: 100% (4/4), 1.28 KiB | 217.00 KiB/s, done.
# Total 4 (delta 2), reused 0 (delta 0)
# remote: Resolving deltas: 100% (2/2), completed with 2 local objects.
# To https://github.com/jeffblackadar/gabii_gis.git
#    d28bd31..7de8e70  main -> main

# %%
# !git branch -m master main

# %%
# !git pull origin main
# Out:
# remote: Enumerating objects: 8, done.
# remote: Counting objects: 100% (8/8), done.
# remote: Compressing objects: 100% (6/6), done.
# remote: Total 6 (delta 4), reused 0 (delta 0), pack-reused 0
# Unpacking objects: 100% (6/6), done.
# From https://github.com/jeffblackadar/gabii_gis
#  * branch            main       -> FETCH_HEAD
#    96cee5c..d28bd31  main       -> origin/main
# Updating 96cee5c..d28bd31
# Fast-forward
#  README.md | 18 +++++++++++++++++-
#  1 file changed, 17 insertions(+), 1 deletion(-)

# %%
# !git rm README.md
# Out:
# README.md: needs merge
# rm 'README.md'

# %%
# !git status
# Out:
# On branch main
# Your branch and 'origin/main' have diverged,
# and have 7 and 8 different commits each, respectively.
#   (use "git pull" to merge the remote branch into yours)
#
# All conflicts fixed but you are still merging.
#   (use "git commit" to conclude merge)
#
# Changes to be committed:
#
# 	new file:   0_git_setup_gabii_gis.ipynb
# 	new file:   1_extract_images_from_pdf.ipynb
# 	deleted:    README.md

# %%
# !git config http.postBuffer 524288000

# %%
# !git pull origin main --allow-unrelated-histories
# Out:
# error: You have not concluded your merge (MERGE_HEAD exists).
# hint: Please, commit your changes before merging.
# fatal: Exiting because of unfinished merge.

# %%
# !git pull origin main
# Out:
# fatal: 'origin' does not appear to be a git repository
# fatal: Could not read from remote repository.
#
# Please make sure you have the correct access rights
# and the repository exists.

# %%
# !git reset --hard
# Out:
# HEAD is now at a5f6c55 3 commit

# %%
# !git push --help

# %%
# !git --version
# Out:
# git version 2.17.1
